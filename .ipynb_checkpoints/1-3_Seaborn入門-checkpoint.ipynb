# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. 折れ線グラフ

# %%
df_weather = pd.read_csv("1-3_weather.csv",index_col="年月日",parse_dates=True)

# %%
sns.set(font="Hiragino Maru Gothic Pro",context="poster",style="white")
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
sns.lineplot(data=df_weather[["平均気温(℃)","降水量の合計(mm)"]])
plt.savefig("折れ線.png")

# %% [markdown]
# # 2. 棒グラフ

# %%
df_score = pd.read_csv("1-3_test_score.csv")

# %%
sns.set(font="Hiragino Maru Gothic Pro",context="talk")
plt.figure(figsize=(10,8))
sns.barplot(data=df_score,y="名前",x="社会",palette="Blues")
# Out:
# <Axes: xlabel='社会', ylabel='名前'>

# %% [markdown]
# # 3. ヒストグラム

# %%
sns.histplot(df_score,
             x="理科",
            binrange=(0,100),
            bins=5,
            hue="クラス",
            hue_order=["1組","2組","3組"],
            multiple="dodge",
            shrink=0.8)
# Out:
# <Axes: xlabel='理科', ylabel='Count'>

# %% [markdown]
# # 4. 散布図（とその仲間たち）

# %% [markdown]
# ## scatterplot:散布図

# %%
plt.figure(figsize=(8,8))
plt.xlim(20,100)
plt.ylim(20,100)
sns.scatterplot(data=df_score,
               x="国語",
               y="算数",
               hue="クラス",
               hue_order=["1組","2組","3組"],
               size="性別")
# Out:
# <Axes: xlabel='国語', ylabel='算数'>

# %% [markdown]
# ## lmplot:回帰直線付き散布図

# %%
sns.lmplot(data=df_score,
               x="国語",
               y="算数",
               hue="クラス",
               hue_order=["1組","2組","3組"],
               height=8)

# %% [markdown]
# ## kdeplot:等高線風散布図

# %%
plt.figure(figsize=(8,8))
plt.xlim(0,150)
plt.ylim(0,150)
sns.kdeplot(data=df_score,
               x="理科",
               y="社会",
               hue="クラス",
               hue_order=["1組","2組","3組"])
# Out:
# <Axes: xlabel='理科', ylabel='社会'>

# %% [markdown]
# ## jointplot:ヒストグラム付き散布図

# %%
sns.jointplot(data=df_score,
               x="国語",
               y="算数",
               hue="クラス",
               hue_order=["1組","2組","3組"],
              height=8)

# %% [markdown]
# ## pairplot:全ペアによる散布図

# %%
sns.pairplot(data=df_score,hue="クラス")

# %% [markdown]
# # 5. 箱ひげ図（とその仲間たち）

# %% [markdown]
# ## boxplot:箱ひげ図

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df_score)
# Out:
# <Axes: >

# %%
df_score_reshape = df_score.melt(["名前","クラス","性別"],var_name="科目",value_name="点数")

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df_score_reshape,
           hue="クラス",
           hue_order=["1組","2組","3組"],
           x="科目",
           y="点数")
# Out:
# <Axes: xlabel='科目', ylabel='点数'>

# %% [markdown]
# ## violinplot:バイオリンプロット

# %%
plt.figure(figsize=(15,8))
sns.violinplot(data=df_score_reshape,
           hue="クラス",
           hue_order=["1組","2組","3組"],
           x="科目",
           y="点数")
# Out:
# <Axes: xlabel='科目', ylabel='点数'>

# %% [markdown]
# ## stripplot:散布図風ヒストグラム

# %%
plt.figure(figsize=(15,8))
sns.stripplot(data=df_score_reshape,
           hue="クラス",
           hue_order=["1組","2組","3組"],
           x="科目",
           y="点数")
# Out:
# <Axes: xlabel='科目', ylabel='点数'>

# %% [markdown]
# ## swarmplot:散布図風ヒストグラム２

# %%
plt.figure(figsize=(15,8))
sns.swarmplot(data=df_score_reshape,
           hue="クラス",
           hue_order=["1組","2組","3組"],
           x="科目",
           y="点数")
# Out:
# <Axes: xlabel='科目', ylabel='点数'>

# %% [markdown]
# # 6. ヒートマップ

# %% [markdown]
# ## heatmap:ヒートマップ

# %%
sns.set(font="Hiragino Maru Gothic Pro",context="talk")
plt.figure(figsize=(8,8))
sns.heatmap(df_score.corr(),
           square=True,
           cmap="Blues",
           annot=True,
           fmt=".2f")
# Out:
# /var/folders/m2/yyrff9ts3qq1t2v3mykdjxtw0000gn/T/ipykernel_75030/1752652128.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_score.corr(),
# <Axes: >

# %% [markdown]
# ## clustermap:階層クラスタ付きヒートマップ

# %%
plt.figure(figsize=(8,8))
sns.clustermap(df_score.corr(),
           cmap="Blues",
           annot=True,
           fmt=".2f")
# Out:
# /var/folders/m2/yyrff9ts3qq1t2v3mykdjxtw0000gn/T/ipykernel_75030/3717061011.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.clustermap(df_score.corr(),
